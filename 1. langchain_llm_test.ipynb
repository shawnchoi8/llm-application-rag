# %%
# %pip install -q langchain-ollama

# %% [markdown]
# # LLM 답변 생성
# - `ChatOllama` 를 활용한 LLM 답변 생성

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b ")

# %%
ai_message = llm.invoke("who is the best soccer player?")

# %%
ai_message.content
